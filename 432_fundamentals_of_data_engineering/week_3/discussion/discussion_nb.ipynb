# %%
import pandas as pd
import numpy as np

# %%
permits = pd.read_json('building-permits.json')
poverty = pd.read_json('iqnk-2tcu.json')

# %%
permits.head().T
# Out:
#                                                      0  \
# id                                             1614287
# permit_                                      100072880
# permit_type             PERMIT - RENOVATION/ALTERATION
# review_type                       STANDARD PLAN REVIEW
# application_start_date         2005-10-14T00:00:00.000
# ...                                                ...
# contact_12_type                                    NaN
# contact_12_name                                    NaN
# contact_12_city                                    NaN
# contact_12_state                                   NaN
# contact_12_zipcode                                 NaN
#
#                                                 1                        2  \
# id                                        1614342                  1614371
# permit_                                 100072909                100072936
# permit_type             PERMIT - NEW CONSTRUCTION           PERMIT - SIGNS
# ...

# %%
x = list(permits.columns)

# %%
z = list(poverty.columns)

# %%
poverty.head()
# Out:
#    community_area community_area_name  birth_rate  general_fertility_rate  \
# 0               1         Rogers Park        16.4                    62.0
# 1               2          West Ridge        17.3                    83.3
# 2               3              Uptown        13.1                    50.5
# 3               4      Lincoln Square        17.1                    61.0
# 4               5        North Center        22.4                    76.2
#
#    low_birth_weight  prenatal_care_beginning_in_first_trimester  \
# 0              11.0                                        73.0
# 1               8.1                                        71.1
# 2               8.3                                        77.7
# 3               8.1                                        80.5
# 4               9.1                                        80.4
#
#    preterm_births  teen_birth_rate  assault_homicide  \
# 0            11.2             40.8               7.7
# ...

# %%
sub = poverty[['community_area_name','unemployment','below_poverty_level']]

# %%
sub['combined_score'] = sub['unemployment'] + sub['below_poverty_level']
sub.sort_values(by='combined_score',ascending=False).head()
# Out:
# C:\Users\TK\AppData\Local\Temp\ipykernel_26428\2692136942.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub['combined_score'] = sub['unemployment'] + sub['below_poverty_level']
#    community_area_name  unemployment  below_poverty_level  combined_score
# 36         Fuller Park          40.0                 55.5            95.5
# 53           Riverdale          26.4                 61.4            87.8
# 66      West Englewood          34.7                 32.3            67.0
# 25  West Garfield Park          25.2                 40.3            65.5
# 35             Oakland          26.6                 38.1            64.7
