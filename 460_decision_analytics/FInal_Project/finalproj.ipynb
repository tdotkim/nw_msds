# %%
import sys
import gurobipy as gp
from gurobipy import GRB
from pulp import LpVariable, LpProblem, LpMaximize, LpStatus, value, LpMinimize, GUROBI_CMD

# %% [markdown]
# ## Variables

# %%
# Widgets Production & Inventory & Marketing
WA1 = LpVariable("Widgets_Plant-A_Period-1", 0, None)
WA2 = LpVariable("Widgets_Plant-A_Period-2", 0, None)
WA3 = LpVariable("Widgets_Plant-A_Period-3", 0, None)
WA4 = LpVariable("Widgets_Plant-A_Period-4", 0, None)
WA5 = LpVariable("Widgets_Plant-A_Period-5", 0, None)

WB1 = LpVariable("Widgets_Plant-B_Period-1", 0, None)
WB2 = LpVariable("Widgets_Plant-B_Period-2", 0, None)
WB3 = LpVariable("Widgets_Plant-B_Period-3", 0, None)
WB4 = LpVariable("Widgets_Plant-B_Period-4", 0, None)
WB5 = LpVariable("Widgets_Plant-B_Period-5", 0, None)

WAI1 = LpVariable("Widgets_Inventory_Plant-A_Period-1", 0, None)
WAI2 = LpVariable("Widgets_Inventory_Plant-A_Period-2", 0, None)
WAI3 = LpVariable("Widgets_Inventory_Plant-A_Period-3", 0, None)
WAI4 = LpVariable("Widgets_Inventory_Plant-A_Period-4", 0, None)
WAI5 = LpVariable("Widgets_Inventory_Plant-A_Period-5", 0, None)

WBI1 = LpVariable("Widgets_Inventory_Plant-B_Period-1", 0, None)
WBI2 = LpVariable("Widgets_Inventory_Plant-B_Period-2", 0, None)
WBI3 = LpVariable("Widgets_Inventory_Plant-B_Period-3", 0, None)
WBI4 = LpVariable("Widgets_Inventory_Plant-B_Period-4", 0, None)
WBI5 = LpVariable("Widgets_Inventory_Plant-B_Period-5", 0, None)

WM1 = LpVariable("Widgets_MarketinW_Period-1", 0, None)
WM2 = LpVariable("Widgets_MarketinW_Period-2", 0, None)
WM3 = LpVariable("Widgets_MarketinW_Period-3", 0, None)
WM4 = LpVariable("Widgets_MarketinW_Period-4", 0, None)
WM5 = LpVariable("Widgets_MarketinW_Period-5", 0, None)

# %%
# Gadgets Production & Inventory & Marketing
GA1 = LpVariable("Gadgets_Plant-A_Period-1", 0, None)
GA2 = LpVariable("Gadgets_Plant-A_Period-2", 0, None)
GA3 = LpVariable("Gadgets_Plant-A_Period-3", 0, None)
GA4 = LpVariable("Gadgets_Plant-A_Period-4", 0, None)
GA5 = LpVariable("Gadgets_Plant-A_Period-5", 0, None)

GB1 = LpVariable("Gadgets_Plant-B_Period-1", 0, None)
GB2 = LpVariable("Gadgets_Plant-B_Period-2", 0, None)
GB3 = LpVariable("Gadgets_Plant-B_Period-3", 0, None)
GB4 = LpVariable("Gadgets_Plant-B_Period-4", 0, None)
GB5 = LpVariable("Gadgets_Plant-B_Period-5", 0, None)

GAI1 = LpVariable("Gadgets_Inventory_Plant-A_Period-1", 0, None)
GAI2 = LpVariable("Gadgets_Inventory_Plant-A_Period-2", 0, None)
GAI3 = LpVariable("Gadgets_Inventory_Plant-A_Period-3", 0, None)
GAI4 = LpVariable("Gadgets_Inventory_Plant-A_Period-4", 0, None)
GAI5 = LpVariable("Gadgets_Inventory_Plant-A_Period-5", 0, None)

GBI1 = LpVariable("Gadgets_Inventory_Plant-B_Period-1", 0, None)
GBI2 = LpVariable("Gadgets_Inventory_Plant-B_Period-2", 0, None)
GBI3 = LpVariable("Gadgets_Inventory_Plant-B_Period-3", 0, None)
GBI4 = LpVariable("Gadgets_Inventory_Plant-B_Period-4", 0, None)
GBI5 = LpVariable("Gadgets_Inventory_Plant-B_Period-5", 0, None)

GM1 = LpVariable("Gadgets_Marketing_Period-1", 0, None)
GM2 = LpVariable("Gadgets_Marketing_Period-2", 0, None)
GM3 = LpVariable("Gadgets_Marketing_Period-3", 0, None)
GM4 = LpVariable("Gadgets_Marketing_Period-4", 0, None)
GM5 = LpVariable("Gadgets_Marketing_Period-5", 0, None)

# %%
# Flugels Production & Inventory & Marketing
FA1 = LpVariable("Flugels_Plant-A_Period-1", 0, None)
FA2 = LpVariable("Flugels_Plant-A_Period-2", 0, None)
FA3 = LpVariable("Flugels_Plant-A_Period-3", 0, None)
FA4 = LpVariable("Flugels_Plant-A_Period-4", 0, None)
FA5 = LpVariable("Flugels_Plant-A_Period-5", 0, None)

FB1 = LpVariable("Flugels_Plant-B_Period-1", 0, None)
FB2 = LpVariable("Flugels_Plant-B_Period-2", 0, None)
FB3 = LpVariable("Flugels_Plant-B_Period-3", 0, None)
FB4 = LpVariable("Flugels_Plant-B_Period-4", 0, None)
FB5 = LpVariable("Flugels_Plant-B_Period-5", 0, None)

FAI1 = LpVariable("Flugels_Inventory_Plant-A_Period-1", 0, None)
FAI2 = LpVariable("Flugels_Inventory_Plant-A_Period-2", 0, None)
FAI3 = LpVariable("Flugels_Inventory_Plant-A_Period-3", 0, None)
FAI4 = LpVariable("Flugels_Inventory_Plant-A_Period-4", 0, None)
FAI5 = LpVariable("Flugels_Inventory_Plant-A_Period-5", 0, None)

FBI1 = LpVariable("Flugels_Inventory_Plant-B_Period-1", 0, None)
FBI2 = LpVariable("Flugels_Inventory_Plant-B_Period-2", 0, None)
FBI3 = LpVariable("Flugels_Inventory_Plant-B_Period-3", 0, None)
FBI4 = LpVariable("Flugels_Inventory_Plant-B_Period-4", 0, None)
FBI5 = LpVariable("Flugels_Inventory_Plant-B_Period-5", 0, None)

FM1 = LpVariable("Flugels_Marketing_Period-1", 0, None)
FM2 = LpVariable("Flugels_Marketing_Period-2", 0, None)
FM3 = LpVariable("Flugels_Marketing_Period-3", 0, None)
FM4 = LpVariable("Flugels_Marketing_Period-4", 0, None)
FM5 = LpVariable("Flugels_Marketing_Period-5", 0, None)

# %%
# Labor
LA1 = LpVariable("Labor_Plant-A_Period-1", 0, None)
LA2 = LpVariable("Labor_Plant-A_Period-2", 0, None)
LA3 = LpVariable("Labor_Plant-A_Period-3", 0, None)
LA4 = LpVariable("Labor_Plant-A_Period-4", 0, None)
LA5 = LpVariable("Labor_Plant-A_Period-5", 0, None)

LOA1 = LpVariable("Labor_Overtime_Plant-A_Period-1", 0, None)
LOA2 = LpVariable("Labor_Overtime_Plant-A_Period-2", 0, None)
LOA3 = LpVariable("Labor_Overtime_Plant-A_Period-3", 0, None)
LOA4 = LpVariable("Labor_Overtime_Plant-A_Period-4", 0, None)
LOA5 = LpVariable("Labor_Overtime_Plant-A_Period-5", 0, None)

LB1 = LpVariable("Labor_Plant-B_Period-1", 0, None)
LB2 = LpVariable("Labor_Plant-B_Period-2", 0, None)
LB3 = LpVariable("Labor_Plant-B_Period-3", 0, None)
LB4 = LpVariable("Labor_Plant-B_Period-4", 0, None)
LB5 = LpVariable("Labor_Plant-B_Period-5", 0, None)

LOB1 = LpVariable("Labor_Overtime_Plant-B_Period-1", 0, None)
LOB2 = LpVariable("Labor_Overtime_Plant-B_Period-2", 0, None)
LOB3 = LpVariable("Labor_Overtime_Plant-B_Period-3", 0, None)
LOB4 = LpVariable("Labor_Overtime_Plant-B_Period-4", 0, None)
LOB5 = LpVariable("Labor_Overtime_Plant-B_Period-5", 0, None)

# %%
RMA1 = LpVariable("Raw-Material-1_Plant-A_Period-1", 0, None)
RMA2 = LpVariable("Raw-Material-1_Plant-A_Period-2", 0, None)
RMA3 = LpVariable("Raw-Material-1_Plant-A_Period-3", 0, None)
RMA4 = LpVariable("Raw-Material-1_Plant-A_Period-4", 0, None)
RMA5 = LpVariable("Raw-Material-1_Plant-A_Period-5", 0, None)

# %%
# Raw Materials
RMA1 = LpVariable("Raw-Material-1_Plant-A_Period-1", 0, None)
RMA2 = LpVariable("Raw-Material-1_Plant-A_Period-2", 0, None)
RMA3 = LpVariable("Raw-Material-1_Plant-A_Period-3", 0, None)
RMA4 = LpVariable("Raw-Material-1_Plant-A_Period-4", 0, None)
RMA5 = LpVariable("Raw-Material-1_Plant-A_Period-5", 0, None)

RMB1 = LpVariable("Raw-Material-1_Plant-B_Period-1", 0, None)
RMB2 = LpVariable("Raw-Material-1_Plant-B_Period-2", 0, None)
RMB3 = LpVariable("Raw-Material-1_Plant-B_Period-3", 0, None)
RMB4 = LpVariable("Raw-Material-1_Plant-B_Period-4", 0, None)
RMB5 = LpVariable("Raw-Material-1_Plant-B_Period-5", 0, None)

RM2A1 = LpVariable("Raw-Material-2_Plant-A_Period-1", 0, None)
RM2A2 = LpVariable("Raw-Material-2_Plant-A_Period-2", 0, None)
RM2A3 = LpVariable("Raw-Material-2_Plant-A_Period-3", 0, None)
RM2A4 = LpVariable("Raw-Material-2_Plant-A_Period-4", 0, None)
RM2A5 = LpVariable("Raw-Material-2_Plant-A_Period-5", 0, None)

RM2B1 = LpVariable("Raw-Material-2_Plant-B_Period-1", 0, None)
RM2B2 = LpVariable("Raw-Material-2_Plant-B_Period-2", 0, None)
RM2B3 = LpVariable("Raw-Material-2_Plant-B_Period-3", 0, None)
RM2B4 = LpVariable("Raw-Material-2_Plant-B_Period-4", 0, None)
RM2B5 = LpVariable("Raw-Material-2_Plant-B_Period-5", 0, None)

# %%
# Transportation
TWA1 = LpVariable("Transportation_Widgets_Plant-A_Period-1", 0, None)
TWA2 = LpVariable("Transportation_Widgets_Plant-A_Period-2", 0, None)
TWA3 = LpVariable("Transportation_Widgets_Plant-A_Period-3", 0, None)
TWA4 = LpVariable("Transportation_Widgets_Plant-A_Period-4", 0, None)
TWA5 = LpVariable("Transportation_Widgets_Plant-A_Period-5", 0, None)

TWB1 = LpVariable("Transportation_Widgets_Plant-B_Period-1", 0, None)
TWB2 = LpVariable("Transportation_Widgets_Plant-B_Period-2", 0, None)
TWB3 = LpVariable("Transportation_Widgets_Plant-B_Period-3", 0, None)
TWB4 = LpVariable("Transportation_Widgets_Plant-B_Period-4", 0, None)
TWB5 = LpVariable("Transportation_Widgets_Plant-B_Period-5", 0, None)

TGA1 = LpVariable("Transportation_Gadgets_Plant-A_Period-1", 0, None)
TGA2 = LpVariable("Transportation_Gadgets_Plant-A_Period-2", 0, None)
TGA3 = LpVariable("Transportation_Gadgets_Plant-A_Period-3", 0, None)
TGA4 = LpVariable("Transportation_Gadgets_Plant-A_Period-4", 0, None)
TGA5 = LpVariable("Transportation_Gadgets_Plant-A_Period-5", 0, None)

TGB1 = LpVariable("Transportation_Gadgets_Plant-B_Period-1", 0, None)
TGB2 = LpVariable("Transportation_Gadgets_Plant-B_Period-2", 0, None)
TGB3 = LpVariable("Transportation_Gadgets_Plant-B_Period-3", 0, None)
TGB4 = LpVariable("Transportation_Gadgets_Plant-B_Period-4", 0, None)
TGB5 = LpVariable("Transportation_Gadgets_Plant-B_Period-5", 0, None)

TFA1 = LpVariable("Transportation_Flugels_Plant-A_Period-1", 0, None)
TFA2 = LpVariable("Transportation_Flugels_Plant-A_Period-2", 0, None)
TFA3 = LpVariable("Transportation_Flugels_Plant-A_Period-3", 0, None)
TFA4 = LpVariable("Transportation_Flugels_Plant-A_Period-4", 0, None)
TFA5 = LpVariable("Transportation_Flugels_Plant-A_Period-5", 0, None)

TFB1 = LpVariable("Transportation_Flugels_Plant-B_Period-1", 0, None)
TFB2 = LpVariable("Transportation_Flugels_Plant-B_Period-2", 0, None)
TFB3 = LpVariable("Transportation_Flugels_Plant-B_Period-3", 0, None)
TFB4 = LpVariable("Transportation_Flugels_Plant-B_Period-4", 0, None)
TFB5 = LpVariable("Transportation_Flugels_Plant-B_Period-5", 0, None)

# %% [markdown]
# ## Objective Function

# %%
# obj function
prob = LpProblem("problem", LpMaximize)

prob += 2490*(WA1+WA2+WA3+WA4+WA5) + \
        2490*(WB1+WB2+WB3+WB4+WB5) + \
        1990*(GA1+GA2+GA3+GA4+GA5) + \
        1990*(GB1+GB2+GB3+GB4+GB5) + \
        2970*(FA1+FA2+FA3+FA4+FA5) + \
        2970*(FB1+FB2+FB3+FB4+FB5) + \
        (-1.25*(RMA1+RMA2+RMA3+RMA4+RMA5)) + \
        (-1.45*(RMB1+RMB2+RMB3+RMB4+RMB5)) + \
        (-2.65*(RM2A1+RM2A2+RM2A3+RM2A4+RM2A5)) + \
        (-2.65*(RM2B1+RM2B2+RM2B3+RM2B4+RM2B5)) + \
        (-11*(LA1+LA2)) + (-11.55*(LA3+LA4+LA5)) + \
        (-16.50*(LOA1+LOA2)) + (-17.33*(LOA3+LOA4+LOA5)) + \
        (-11*(LB1+LB2)) + (-12.10*(LB3+LB4+LB5)) + \
        (-16.50*(LOB1+LOB2)) + (-18.15*(LOB3+LOB4+LOB5))

# %%
# NO JEEP
# variables
c = LpVariable("Cars", 0, None)
t = LpVariable("Trucks", 0, None)
m1 = LpVariable("Machine 1s", 0, None)
m2 = LpVariable("Machine 2s", 0, None)

# defines the problem
prob = LpProblem("problem", LpMaximize)

# objective function
prob += 300*c + 400*t - 50*m1

# define constraints
prob += c >= 88 # marketing constraint for cars, at least 88
prob += t >= 26 # marketing constraint, at least 26
prob += 2*c + 3*t <= 260 # cars cost 2 steel and trucks cost 3 steel with a max of 260 steel
# total number of cars made minus machine 1s used must be < or = to 0 
#(can't make more vehicles using machine 1 than the number of machine 1s)
prob += .8*c + t - m1 <= 0
prob += m1 <= 98 # can only rent up to 98 Machine 1s

prob += .6*c + .7*t <= 73 # (can't make more vehicles using machine 2 than the number of machine 2s)



# solve the problem
prob.writeLP("prob2.lp")
prob.solve(GUROBI_CMD())
print ("Status:", LpStatus[prob.status])

for v in prob.variables():
    print(v.name, "=", v.varValue)

print ("Objective", value(prob.objective))
print ("")

# %%
# pass the model to Gurobi
# we pass to get additional information not available in the pulp model

model = gp.read('prob2.lp')
model.optimize()

# %%
# get the sensitivity analysis from the Gurobi model

print("Decision Variables*******")
model.printAttr(['X','OBJ','SAObjLow','SAObjUp'])

print("\nDecision Variables Additional Info (LB/UB)*******")
model.printAttr(['X','RC','LB','SALBLow','SALBUp','UB','SAUBLow','SAUBUp'])

print("\nDual Info*******")
model.printAttr(['Sense','Slack','Pi','RHS','SARHSLow','SARHSUp'])
